# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

Fs = 1000 # sampling frequency [Hz]
t_max = 2 # measurement time [s]
f1 = 150 # signal 1 frequency [Hz]
m = 7 # harmonic component
f2 = m*f1 # signal 2 frequency [Hz]
A = 2 # amplitude [mm]


k = 1/Fs
t = np.arange(0, t_max, k)
omega1 = 2*np.pi*f1
omega2 = 2*np.pi*f2

x = A*np.sin(omega1*t) + A*np.sin(omega2*t) 

plt.plot(t, x)
plt.title('Spectral analysis')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.show()


n = len(x)
y = abs(fft(x))/(n/2)
y = y[0:int(n/2)]

plt.plot(y)
plt.title('Fourier transform')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Normalized amplitude')
plt.show()


plt.specgram(x, Fs = Fs);
plt.xlim(0, 2)
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.show()
